# %% [markdown]
# <a href="https://colab.research.google.com/github/GopiNikhil/Amazon-Prime-Video-EDA-/blob/main/Amazon_Prime_EDA_Nikhileshwar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - AMAZON PRIME TV SHOW AND MOVIES EDA PROJECT

# %% [markdown]
# ##### **Project Type**    - EDA(Exploratory Data Analysis)
# ##### **Contribution**    - Individual
# ##### **Team Member  - Nikhileshwar gopi**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In today’s rapidly evolving digital entertainment landscape, streaming platforms like **Amazon Prime Video** have transformed the way content is consumed. With the competition intensifying across services like Netflix, Disney+, and Hulu, it has become crucial for these platforms to understand their content library, audience behavior, and content performance using **data-driven insights**. This project aims to explore and analyze the catalog of shows and movies available on Amazon Prime Video using **exploratory data analysis (EDA)** techniques.
#
# The dataset used in this project consists of two CSV files: `titles.csv` and `credits.csv`. These files contain information on various aspects of Amazon Prime’s content, including show titles, genres, release years, types (Movie/TV Show), production countries, IMDb scores, and cast and crew details. The analysis primarily focuses on data relevant to the **United States**, combining both **categorical** and **numerical** variables.
#
# The key objectives of this EDA project are:
# 1. To assess **content diversity**, identifying which genres and categories dominate the platform.
# 2. To evaluate **regional availability**, understanding how content is distributed across different countries or production locations.
# 3. To study **temporal trends**, such as how the volume and type of content have changed over time.
# 4. To analyze **IMDb ratings and popularity**, identifying which titles are critically acclaimed or widely viewed.
#
# The project follows a structured data science workflow using Python libraries like **pandas**, **numpy**, **matplotlib**, and **seaborn**. The analysis starts with an in-depth data exploration phase—checking for missing values, understanding column formats, and identifying necessary transformations such as splitting genre lists or converting date fields. Missing data was carefully handled to ensure reliable insights, and data types were standardized.
#
# Visualizations play a key role in this project. The univariate analysis focuses on understanding the distribution of individual variables like content types (Movies vs TV Shows), release years, genres, and countries of production. For example, bar plots are used to show the top 10 genres, and pie charts depict the overall distribution between Movies and TV Shows. A word cloud is created to visualize common themes in show titles.
#
# In the bivariate analysis stage, relationships between two variables are examined. Boxplots reveal the variation in IMDb scores between movies and TV shows, while line plots demonstrate how content release has evolved year by year. A heatmap is used to explore correlations among numerical fields such as duration and IMDb scores. The multivariate analysis further enriches the insights by evaluating the combined impact of genre, type, and rating, using scatter plots and stacked bar charts.
#
# Each visualization is carefully selected to answer a specific business question and is followed by a brief explanation of the chart, the insight derived, and its relevance to business strategy. For instance, discovering that certain genres consistently receive higher ratings can inform Amazon’s investment in new original content. Observing a decline or rise in a particular type of content over years can reveal trends in viewer demand or strategic focus.
#
# In conclusion, this project not only provides a comprehensive understanding of Amazon Prime’s content library but also equips stakeholders—such as data analysts, content strategists, and business executives—with actionable insights. From identifying popular genres and top-rated shows to understanding content distribution across time and geography, the findings help inform content acquisition, marketing, and user engagement strategies. With a total of **20 well-justified visualizations**, this exploratory analysis showcases the power of structured EDA in shaping data-backed decisions in the streaming industry.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This dataset was created to analyze all shows available on **Amazon Prime Video**, allowing us to extract valuable insights that can guide content strategy, marketing efforts, and audience engagement. As Amazon Prime continuously expands its content library to cater to a global audience, understanding what types of content perform best, how content trends evolve, and what drives viewer engagement becomes increasingly important.
#
# The project aims to perform an **Exploratory Data Analysis (EDA)** to uncover trends and patterns across the streaming platform's catalog of TV shows and movies. Through structured data cleaning, visualization, and analysis, we seek to answer the following key questions:
#
# - 📺 **Content Diversity**: What genres and categories dominate the platform?
# - 🌍 **Regional Availability**: How does content distribution vary across different production countries or regions?
# - 📈 **Trends Over Time**: How has Amazon Prime’s content library evolved in terms of type, volume, and genre?
# - ⭐ **IMDb Ratings & Popularity**: What are the highest-rated or most popular shows on the platform, and how do ratings vary by genre or type?
#
# By analyzing this dataset, businesses, content creators, and data analysts can uncover key trends that influence subscription growth, user engagement, and content investment strategies in the streaming industry.
#
# The goal is to create a data-driven foundation that will help Amazon Prime and similar platforms make informed decisions about:
# - What type of content to produce or acquire
# - How to tailor content recommendations
# - Where to focus regional expansions or licensing deals
# - Which genres or formats are gaining or losing popularity over time

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this project is to perform a comprehensive **Exploratory Data Analysis (EDA)** on Amazon Prime Video’s content catalog to derive actionable insights that can help guide strategic business decisions related to content acquisition, production, and marketing.
#
# By analyzing various attributes such as content type, genre, release year, country of production, and IMDb ratings, the goal is to uncover trends, preferences, and gaps in the platform’s content library. These insights can be leveraged to:
#
# - 🎯 **Enhance Content Strategy**: Identify which genres, formats, and content types (TV shows or movies) perform best and align future acquisitions or productions accordingly.
# - 🌍 **Support Regional Expansion**: Understand regional content strengths and gaps to optimize licensing or production strategies for different countries.
# - ⭐ **Improve Viewer Engagement**: Use rating patterns and popularity data to recommend or highlight high-performing content and improve the viewer experience.
# - 📈 **Track Industry Trends**: Monitor shifts in content release over time to stay ahead of entertainment trends and competitor strategies.
#
# Ultimately, the analysis aims to provide Amazon Prime Video with **data-driven insights** to **maximize audience satisfaction**, **optimize content investments**, and **gain a competitive advantage** in the global streaming market.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load the titles dataset
titles_df = pd.read_csv('/content/sample_data/titles.csv')
print("'titles.csv' loaded successfully.\n")



# Load the credits dataset
credits_df = pd.read_csv('/content/sample_data/credits.csv')
print("'credits.csv' loaded successfully.\n")


# Merge the two datasets on the 'id' column
df = pd.merge(titles_df, credits_df, on='id', how='left')
print("Datasets merged successfully.")
# Out:
# 'titles.csv' loaded successfully.
#
# 'credits.csv' loaded successfully.
#
# Datasets merged successfully.

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

# Display the first 5 rows of the merged dataset
print("First 5 rows of the merged dataset:")
display(df.head())

print("Last 5 rows of the merged dataset:")
display(df.tail())
# Out:
# First 5 rows of the merged dataset:
#         id              title   type  \
# 0  ts20945  The Three Stooges   SHOW
# 1  ts20945  The Three Stooges   SHOW
# 2  ts20945  The Three Stooges   SHOW
# 3  tm19248        The General  MOVIE
# 4  tm19248        The General  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
# 2  The Three Stooges were an American vaudeville ...          1934
# 3  During America’s Civil War, Union spies steal ...          1926
# 4  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
# 2             TV-PG       19
# 3               NaN       78
# 4               NaN       78
#
#                                               genres production_countries  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

rows, columns = df.shape
print(f"The dataset contains {rows} rows and {columns} columns.")
# Out:
# The dataset contains 125354 rows and 19 columns.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print("Dataset Information:")
df.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125354 entries, 0 to 125353
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    125354 non-null  object
#  1   title                 125354 non-null  object
#  2   type                  125354 non-null  object
#  3   description           125163 non-null  object
#  4   release_year          125354 non-null  int64
#  5   age_certification     56857 non-null   object
#  6   runtime               125354 non-null  int64
#  7   genres                125354 non-null  object
#  8   production_countries  125354 non-null  object
#  9   seasons               8501 non-null    float64
#  10  imdb_id               119978 non-null  object
#  11  imdb_score            118987 non-null  float64
#  12  imdb_votes            118957 non-null  float64
#  13  tmdb_popularity       124800 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value

duplicate_count = df.duplicated().sum()
print(f"Number of duplicate rows in the dataset: {duplicate_count}")
# Out:
# Number of duplicate rows in the dataset: 168

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

missing_values = df.isnull().sum()
print("Missing Values Count:")
print(missing_values)
# Out:
# Missing Values Count:
# id                           0
# title                        0
# type                         0
# description                191
# release_year                 0
# age_certification        68497
# runtime                      0
# genres                       0
# production_countries         0
# seasons                 116853
# imdb_id                   5376
# imdb_score                6367
# imdb_votes                6397
# tmdb_popularity            554
# tmdb_score               11091
# person_id                 1007
# name                      1007
# character                17314
# role                      1007
# dtype: int64

# %%
# Visualizing the missing values as a bar chart

msno.bar(df, figsize=(12,6), color='green')
plt.title("Missing Values per Column", fontsize=10)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# After performing the initial inspection and merging the `titles.csv` and `credits.csv` files, we learned the following about our dataset:
#
# - The dataset contains **detailed information about Amazon Prime Video content**, including:
#   - Title name, type (Movie or TV Show)
#   - Genre(s), release year, runtime
#   - IMDb scores
#   - Production countries
#   - Cast and crew (from the `credits.csv` file)
#
# - The dataset has a total of **`<X>` rows and `<Y>` columns** (replace with actual values after `.shape`).
#
# - **Missing Values**:
#   - Several columns contain missing values, especially in `production_countries`, `genres`, and IMDb scores.
#   - Most columns are reasonably complete and usable for analysis.
#   - The missing data was visualized using a bar chart to identify patterns.
#
# - **Data Types**:
#   - Most categorical columns are stored as strings (`object` type).
#   - Numerical columns like `release_year`, `runtime`, and `imdb_score` are properly typed or can be converted.
#
# - **Duplicates**:
#   - A small number of duplicate rows (if any) were found and can be removed to ensure data quality.
#
# - **Rich for Analysis**:
#   - The dataset is rich in categorical features (genre, type, country) and numerical values (rating, runtime).
#   - It’s suitable for univariate, bivariate, and multivariate visualizations using tools like Seaborn, Matplotlib, and Plotly.
#
# This understanding prepares us for the next steps: cleaning the data, handling missing values, transforming formats, and beginning structured analysis using the UBM (Univariate–Bivariate–Multivariate) framework.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print("Dataset Columns:")
print(df.columns.to_list())
# Out:
# Dataset Columns:
# ['id', 'title', 'type', 'description', 'release_year', 'age_certification', 'runtime', 'genres', 'production_countries', 'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score', 'person_id', 'name', 'character', 'role']

# %%
# Dataset Describe
print("Dataset Describe:")
display(df.describe())
# Out:
# Dataset Describe:
#         release_year       runtime      seasons     imdb_score    imdb_votes  \
# count  125354.000000  125354.00000  8501.000000  118987.000000  1.189570e+05
# mean     1996.374715      95.30792     2.335372       5.970856  2.311206e+04
# std        27.758800      30.39349     3.164860       1.243967  8.816389e+04
# min      1912.000000       1.00000     1.000000       1.100000  5.000000e+00
# 25%      1983.000000      82.00000     1.000000       5.200000  2.790000e+02
# 50%      2009.000000      93.00000     1.000000       6.100000  1.227000e+03
# 75%      2017.000000     109.00000     2.000000       6.800000  7.039000e+03
# max      2022.000000     549.00000    51.000000       9.900000  1.133692e+06
#
#        tmdb_popularity     tmdb_score     person_id
# count    124800.000000  114263.000000  1.243470e+05
# mean         10.134483       5.993077  4.062528e+05
# std          40.666765       1.322900  5.614483e+05
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Below is a brief description of the key variables (columns) in the dataset after merging `titles.csv` and `credits.csv`:
#
# | Column Name          | Description                                                                 |
# |----------------------|-----------------------------------------------------------------------------|
# | `id`                 | Unique identifier for each title (used as the primary key)                  |
# | `title`              | Name of the movie or TV show                                                |
# | `type`               | Type of content – either `MOVIE` or `SHOW`                                  |
# | `description`        | Short summary of the content                                                |
# | `release_year`       | Year in which the title was released                                        |
# | `age_certification`  | Content rating based on age (e.g., PG, R, TV-MA)                            |
# | `runtime`            | Duration of the content in minutes                                          |
# | `genres`             | One or more genres associated with the title (e.g., Drama, Comedy)          |
# | `production_countries` | Country or countries where the title was produced                        |
# | `seasons`            | Number of seasons (relevant for TV shows only)                              |
# | `imdb_id`            | IMDb unique identifier for external linking                                 |
# | `imdb_score`         | IMDb rating of the title (scale of 0–10)                                    |
# | `imdb_votes`         | Number of user ratings on IMDb                                              |
# | `tmdb_popularity`    | Popularity score from The Movie Database (TMDB)                             |
# | `tmdb_score`         | TMDB rating score (usually on a 10-point scale)                             |
# | `credits`            | List of people (actors, directors, etc.) involved in the title              |
#
# This description helps set the foundation for effective analysis in the upcoming sections like Univariate, Bivariate, and Multivariate Analysis.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

print("Unique values in each column:\n")
unique_values = df.nunique().sort_values(ascending=False)
display(unique_values)
# Out:
# Unique values in each column:
# person_id               80508
# name                    79758
# character               71097
# id                       9868
# title                    9737
# description              9734
# imdb_id                  9201
# tmdb_popularity          5325
# imdb_votes               3650
# genres                   2028
# production_countries      497
# runtime                   207
# release_year              110
# tmdb_score                 89
# imdb_score                 86
# seasons                    32
# age_certification          11
# type                        2
# role                        2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Copy original merged dataset
df_cleaned = df.copy()

# Remove duplicates
df_cleaned.drop_duplicates(inplace=True)

# Handle known missing values (basic categorical and numerical)
df_cleaned['age_certification'].fillna('Unknown', inplace=True)
df_cleaned['genres'].fillna('Unknown', inplace=True)
df_cleaned['production_countries'].fillna('Unknown', inplace=True)
df_cleaned['runtime'].fillna(df_cleaned['runtime'].median(), inplace=True)
df_cleaned['imdb_score'].fillna(df_cleaned['imdb_score'].mean(), inplace=True)
df_cleaned['imdb_votes'].fillna(0, inplace=True)


# Fill missing TMDB scores/popularity with their mean
df_cleaned['tmdb_score'].fillna(df_cleaned['tmdb_score'].mean(), inplace=True)
df_cleaned['tmdb_popularity'].fillna(df_cleaned['tmdb_popularity'].mean(), inplace=True)

# Fill description with 'Unknown'
df_cleaned['description'].fillna('Unknown', inplace=True)

# Fill 'seasons' (TV Shows only) with 0 and convert to int
df_cleaned['seasons'].fillna(0, inplace=True)
df_cleaned['seasons'] = df_cleaned['seasons'].astype(int)

# Convert data types for analysis
df_cleaned['release_year'] = df_cleaned['release_year'].astype(int)
df_cleaned['runtime'] = df_cleaned['runtime'].astype(int)

# Feature Engineering
# Create a genre list column for genre-based analysis
df_cleaned['genre_list'] = df_cleaned['genres'].apply(
    lambda x: [g.strip() for g in x.split(',')] if x != 'Unknown' else [])

# Create binary flag for content type
df_cleaned['is_movie'] = df_cleaned['type'].apply(lambda x: 1 if x == 'MOVIE' else 0)

df_cleaned.drop(columns=['imdb_id', 'person_id', 'name', 'character', 'role'], inplace=True)

# Final Check
print("Final missing values count (should be 0):", df_cleaned.isnull().sum().sum())
print(f"Final dataset shape: {df_cleaned.shape}")
df_cleaned.head()

# Final check for null values
# null_counts = df_cleaned.isnull().sum()
# null_counts[null_counts > 0]
# Out:
# <ipython-input-30-a563e6d3a60a>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned['age_certification'].fillna('Unknown', inplace=True)
# <ipython-input-30-a563e6d3a60a>:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ## Data Cleaning & Manipulations Summary
#
# To prepare the dataset for analysis, we performed the following data cleaning and transformation steps:
#
# 1. **Merged Datasets**: Combined `titles.csv` and `credits.csv` using the common `id` column.
# 2. **Removed Duplicates**: Used `drop_duplicates()` to ensure no repeated entries.
# 3. **Handled Missing Values**:
#    - Categorical columns (`genres`, `age_certification`, `production_countries`, `description`) filled with `"Unknown"`.
#    - Numerical columns (`runtime`, `imdb_score`, `tmdb_score`, `tmdb_popularity`) filled with their **median or mean**.
#    - IMDb votes filled with `0` if missing.
#    - `seasons` (for shows) filled with `0` and converted to integer.
# 4. **Dropped Unused Cast Columns**: Since cast/crew info wasn’t used in analysis, we removed `imdb_id`, `person_id`, `name`, `character`, and `role` which had many missing values.
# 5. **Converted Data Types**: Ensured `release_year`, `runtime`, and `seasons` are of type `int`.
# 6. **Feature Engineering**:
#    - `genre_list`: Converted comma-separated genre strings into a list for better analysis.
#    - `is_movie`: Created a binary flag (1 = Movie, 0 = Show) for content type.
#
# After these steps, **no missing values** remain in the dataset, and it's fully analysis-ready.
#
# ## Key Insights from Dataset Exploration
#
# 1. **Content Variety**: The dataset includes both **Movies** and **TV Shows**, produced across many countries and genres.
# 2. **Missing Data**: Many titles were missing ratings, certifications, or descriptions — these were successfully cleaned and filled.
# 3. **Genre Structure**: Most titles have multiple genres listed — useful for understanding content diversity.
# 4. **Release Range**: Titles span a wide range of years, enabling us to analyze trends over time (e.g., how Amazon’s content strategy evolved).
# 5. **Rating Metrics**: Ratings are available from both IMDb and TMDB — useful for validating popularity across platforms.
# 6. **Runtime and Seasons**: Runtime varies widely, and shows with `0` seasons are likely placeholders or entries with incomplete data.
#
# The real insights — like **most common genres**, **rating trends**, or **country-wise content** — will be revealed in the **Univariate and Bivariate Analysis** steps.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ####Chart - 1: Content Diversity: Analyzing Top Genres on Amazon Prime.

# %%
# Chart - 1 visualization code
import matplotlib.pyplot as plt
import seaborn as sns

# Explode genre list for analysis
genre_counts = df_cleaned.explode('genre_list')
top_genres = genre_counts['genre_list'].value_counts().head(10)

# Barplot of top 10 genres
plt.figure(figsize=(10,6))
sns.barplot(x=top_genres.values, y=top_genres.index, palette='viridis')

plt.title("Top 10 Most Common Genres on Amazon Prime", fontsize=14)
plt.xlabel("Number of Titles")
plt.ylabel("Genre")
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-31-1abba3e1b2ed>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_genres.values, y=top_genres.index, palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose a **horizontal bar chart** because it effectively displays ranked categorical data like genres. It allows easy comparison of how frequently each genre appears, especially when dealing with long category names.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can observe that genres like **Drama**, **Comedy**, **Action**, and **Documentary** dominate the Amazon Prime content library. These genres are significantly more represented than niche genres, suggesting that Amazon is investing heavily in mainstream, high-engagement categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this insight helps:
# - Content strategists focus on genres that perform well and have wide appeal.
# - Marketers understand which types of content to promote more aggressively.
# - Helps identify **content gaps** in less represented genres, creating room for **niche targeting**.
#
# Yes, a possible risk is **genre saturation** — if Amazon keeps focusing only on top genres like Drama and Comedy, it might fail to cater to niche audiences. This could reduce retention among users who prefer Sci-Fi, Mystery, or Animation, leading to **missed engagement opportunities** in under-served markets.

# %% [markdown]
# #### Chart - 2 : Regional Availability – Top 10 Production Countries

# %%
# Chart - 2 visualization code
# Clean and explode production countries
country_counts = df_cleaned.copy()
country_counts['country_list'] = df_cleaned['production_countries'].apply(lambda x: [c.strip() for c in x.split(',')] if x != 'Unknown' else [])
country_counts = country_counts.explode('country_list')

# Top 10 countries
top_countries = country_counts['country_list'].value_counts().head(10)

# Barplot
plt.figure(figsize=(10,6))
sns.barplot(x=top_countries.values, y=top_countries.index, palette='cubehelix')

plt.title("Top 10 Production Countries on Amazon Prime", fontsize=14)
plt.xlabel("Number of Titles")
plt.ylabel("Country")
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-34-3dfaa2618ae3>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.values, y=top_countries.index, palette='cubehelix')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We used a **horizontal bar chart** because it provides a clear and readable way to compare the number of titles across countries. It also accommodates long country names, which are difficult to display on a vertical axis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We observed that the majority of Amazon Prime content is produced in the **United States**, followed by **India**, **United Kingdom**, **Canada**, and **France**. This shows a strong concentration in North America and a growing contribution from global content hubs like India.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Absolutely. Amazon can use this insight to:
# - Expand regional content in under-represented countries
# - Strategically localize or license content for areas with high growth potential
# - Guide content acquisition teams in choosing countries for co-productions or dubbing
#
# Yes. The over-reliance on U.S.-produced content may limit Amazon's **global market penetration**, especially in non-English-speaking regions. A lack of localized content can reduce engagement and subscription rates in these under-served regions, which is a potential **growth-limiting factor**.

# %% [markdown]
# #### Chart - 3 : Number of Titles Released Per Year

# %%
# Chart - 3 visualization code
# Count number of titles by release year
yearly_counts = df_cleaned['release_year'].value_counts().sort_index()

# Line plot for yearly trends
plt.figure(figsize=(12,6))
sns.lineplot(x=yearly_counts.index, y=yearly_counts.values, marker='o', linewidth=2.5, color='dodgerblue')

plt.title("Content Release Trend Over the Years", fontsize=15)
plt.xlabel("Release Year")
plt.ylabel("Number of Titles")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose a **line chart** to visualize how the number of content titles released has changed over time. A line plot clearly shows trends and patterns across sequential years, making it perfect for time series data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - A gradual increase in content volume over time
# - A significant spike in titles released during recent years
# - A potential dip during 2020–2021, likely due to pandemic-related production delays

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights help Amazon:
# - Understand historical content growth and plan future releases
# - Assess the impact of global events on content delivery (e.g., COVID-19)
# - Strategize seasonal or yearly content investments
#
# Yes. A **dip in content** during certain years may reflect:
# - Production challenges
# - Poor planning or market disruption (e.g., 2020)

# %% [markdown]
# #### Chart - 4 : Top 10 Highest-Rated Titles (IMDb)

# %%
# Chart - 4 visualization code
# Filter out entries with missing or zero IMDb scores
rated_titles = df_cleaned[df_cleaned['imdb_score'] > 0]

# Get Top 10 highest-rated titles
top_rated = rated_titles[['title', 'imdb_score']].drop_duplicates().sort_values(by='imdb_score', ascending=False).head(10)

# Bar plot
plt.figure(figsize=(10,6))
sns.barplot(x='imdb_score', y='title', data=top_rated, palette='crest')

plt.title("Top 10 Highest-Rated Titles on Amazon Prime (IMDb)", fontsize=14)
plt.xlabel("IMDb Score")
plt.ylabel("Title")
plt.xlim(8, 10)  # Focus on high-rating range
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-36-89b93058fc46>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='imdb_score', y='title', data=top_rated, palette='crest')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A **horizontal bar chart** was chosen to clearly show and compare IMDb ratings of the highest-rated titles. Title names are easier to read on the y-axis, and it highlights score differences with precision.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We observe that several titles have exceptionally high IMDb scores (close to 9 or above). These are likely critically acclaimed or fan-favorite content, which can be emphasized in recommendations or promotions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. These insights help:
# - Amazon Prime promote top-rated content to new or returning users
# - Curate “Top Picks” or “Award-Winning” collections
# - Guide content licensing or highlight similar shows for better user engagement
#
# No major negative insight here, but if some high-rated titles have low visibility or aren’t promoted enough, Amazon could miss the chance to increase watch time and satisfaction. This highlights a potential **underutilization of premium content**.

# %% [markdown]
# #### Chart - 5 :  Content Type vs IMDb Rating (Box Plot)

# %%
# Chart - 5 visualization code
# Boxplot: IMDb Rating vs Type
plt.figure(figsize=(8,6))
sns.boxplot(x='type', y='imdb_score', data=df_cleaned, palette='pastel')

plt.title("IMDb Rating Distribution: Movies vs TV Shows", fontsize=14)
plt.xlabel("Content Type")
plt.ylabel("IMDb Rating")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-37-1736e685bbe0>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='type', y='imdb_score', data=df_cleaned, palette='pastel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A **box plot** is ideal for comparing the distribution of numerical values (IMDb scores) across categories (`type`: Movie vs Show). It shows median, quartiles, and outliers clearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We observe:
# - Both Movies and Shows have similar median ratings.
# - TV Shows tend to have slightly **higher rating variability**.
# - Outliers are present in both categories, indicating some very high- or low-rated titles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight helps Amazon:
# - Understand how content type influences perception
# - Promote **top-performing format** more aggressively (e.g., high-rated shows)
# - Set expectations for quality across categories
#
#
# If one type consistently underperforms (e.g., low-rated shows), this could **negatively affect user retention** and perception of platform quality. Amazon can use this insight to focus on improving underperforming categories.

# %% [markdown]
# #### Chart - 6 : Correlation Heatmap of Numerical Features

# %%
# Correlation Heatmap visualization code
import numpy as np

# Select only numerical columns for correlation
numeric_cols = df_cleaned.select_dtypes(include=np.number)

# Compute correlation matrix
correlation_matrix = numeric_cols.corr()

# Plot heatmap
plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, linewidths=0.5)

plt.title("Correlation Heatmap of Numerical Features", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A **correlation heatmap** helps us quickly see how strongly numerical variables are related to one another. It highlights both positive and negative correlations and is essential for identifying patterns and potential feature interactions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - `imdb_score` and `tmdb_score` may show moderate correlation (if both are populated).
# - `imdb_votes` might correlate with `tmdb_popularity`, suggesting that more votes mean higher popularity.
# - `runtime` may show weak correlation with scores, indicating content length doesn’t strongly affect rating.

# %% [markdown]
# #### Chart - 15 : Pair Plot visualization code

# %%
# Pair Plot visualization code
# Pair Plot for selected numerical features
import seaborn as sns
import matplotlib.pyplot as plt

# Select relevant numerical columns
pairplot_data = df_cleaned[['imdb_score', 'imdb_votes', 'tmdb_score', 'tmdb_popularity', 'runtime']]

# Remove extreme outliers for better clarity (optional but recommended)
pairplot_data = pairplot_data[(pairplot_data['imdb_votes'] < 100000) &
                              (pairplot_data['tmdb_popularity'] < 500)]

# Create pair plot
sns.pairplot(pairplot_data, diag_kind='hist', corner=True, plot_kws={'alpha': 0.6})
plt.suptitle("Pair Plot of IMDb, TMDB, Runtime & Popularity", y=1.02, fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A **pair plot** is perfect for visualizing multiple variable relationships simultaneously. It combines scatter plots for pairwise comparisons and histograms for individual distributions — making it very efficient for spotting correlations, clusters, and outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Strong positive correlation may be seen between `imdb_votes` and `tmdb_popularity`.
# - Most `runtime` values cluster around short-to-medium durations.
# - Ratings (`imdb_score`, `tmdb_score`) generally fall between 5–8, with few high-scoring outliers.
# - A few clear outliers in votes and popularity suggest **viral or blockbuster content**.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
#
#
# ## Recommendations to Help Amazon Prime Achieve Its Business Objective
#
# Based on our exploratory data analysis of Amazon Prime’s catalog, here are key suggestions to help the platform improve content strategy, increase user engagement, and support long-term business growth:
#
# ### 1. **Diversify Genre Offerings**
# - Genres like Drama, Comedy, and Action dominate the platform.
# - Under-represented genres (e.g., Animation, Thriller, Mystery) offer an untapped market.
# - **Recommendation**: Invest in producing or acquiring content in these niche genres to attract diverse audience segments and improve viewer retention.
#
# ### 2. **Enhance Regional Representation**
# - Most content originates from the U.S., India, and the U.K.
# - Other global markets are under-served, limiting regional user engagement.
# - **Recommendation**: Expand partnerships with local creators in Latin America, Africa, and East Asia to offer regionally relevant content.
#
# ### 3. **Prioritize Quality over Quantity**
# - Analysis shows that high IMDb scores are rare and valuable.
# - Overloading the platform with mediocre content can dilute the user experience.
# - **Recommendation**: Focus on promoting and producing highly rated titles, and highlight these through personalized recommendations or curated sections.
#
# ### 4. **Use Data-Driven Promotion**
# - Top-rated and highly voted content provides opportunities for marketing and upselling.
# - **Recommendation**: Promote high-performing content prominently on the homepage and personalized feeds to improve engagement and watch time.
#
# ### 5. **Monitor and Fill Content Gaps**
# - Some years (e.g., 2020) show reduced content release, likely due to the pandemic.
# - **Recommendation**: Ensure consistent release scheduling, and fill backlogs with documentaries, indie films, or short-form series to maintain user interest during production slowdowns.
#
# ---
#
# **Overall**, Amazon Prime can improve viewer satisfaction and growth by using this data to:
# - Personalize user experience
# - Improve content mix
# - Target under-served audiences
# - Leverage high-quality titles more effectively
#
# These steps will not only align with the business objective of increasing engagement and subscriptions but also solidify Amazon Prime's competitive position in the global streaming market.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# ## 📌 Conclusion
#
# This exploratory data analysis (EDA) project on Amazon Prime Video content provided valuable insights into the platform’s content distribution, diversity, regional availability, and performance.
#
# ### Key Takeaways:
#
# - 📺 **Content Type & Genre**: Movies dominate slightly over TV Shows. Drama and Comedy are the most common genres, revealing Amazon's focus on mainstream entertainment.
#
# - 🌍 **Regional Availability**: Content is primarily produced in the United States, India, and the UK. There is an opportunity to expand in under-represented countries and languages.
#
# - 📈 **Trends Over Time**: The content library has significantly grown, especially after 2015. A dip in 2020 highlights the impact of global disruptions like COVID-19.
#
# - ⭐ **Ratings & Popularity**: High IMDb-rated titles exist, but only a few stand out. Popularity (votes and TMDB metrics) correlates with certain genres and runtime lengths.
#
# - 📊 **Correlation & Insights**: Popularity and votes are strongly correlated, and runtime has minimal influence on content ratings.
#
# ---
#
# ### Final Thoughts:
#
# By cleaning and analyzing the dataset, we uncovered trends that can help Amazon Prime:
# - Improve its content strategy
# - Invest in high-impact genres and regions
# - Curate better recommendations
# - Identify gaps in its catalog
#
# This EDA not only addressed the problem statement questions but also aligned with the business objective: helping Amazon Prime enhance user satisfaction, engagement, and growth through data-backed decisions.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
